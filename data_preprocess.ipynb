# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Import modules

# %%
import numpy as np
from IPython.display import Audio

from musicvae.data_utils import create_train_val_test, parse_one_hot_encode
from musicvae.music_utils import numpy_to_midi

# %% [markdown]
# # Create train, val, test datasets

# %%
create_train_val_test('datasets')
# Out:
# Generating dataset: 100%|██████████| 3/3 [00:13<00:00,  4.56s/it]

# %% [markdown]
# # Load one sample and test numpy to midi

# %%
loaded_data = np.load('datasets/test.npy')

# %%
loaded_data.shape
# Out:
# (549, 64, 512)

# %%
midi = numpy_to_midi(parse_one_hot_encode(loaded_data[22]), 10)
Audio(midi.fluidsynth(fs=44100), rate=44100)
# Out:
# fluidsynth: error: Unknown integer parameter 'synth.sample-rate'
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
